# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Jan-Sep 2020_citibike tripdata (use).csv')
df.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           226   04:50.2  08:37.0              3186      Grove St PATH
# 1           377   16:01.7  22:19.1              3186      Grove St PATH
# 2           288   17:33.9  22:22.4              3186      Grove St PATH
# 3           435   32:05.9  39:21.1              3195            Sip Ave
# 4           231   46:19.7  50:11.3              3186      Grove St PATH
#
#    start station latitude  start station longitude  end station id  \
# 0               40.719586               -74.043117            3211
# 1               40.719586               -74.043117            3269
# 2               40.719586               -74.043117            3269
# 3               40.730897               -74.063913            3280
# 4               40.719586               -74.043117            3276
#
#    end station name  end station latitude  end station longitude  bikeid  \
# 0        Newark Ave             40.721525             -74.046305   29444
# 1   Brunswick & 6th             40.726012             -74.050389   26305
# 2   Brunswick & 6th             40.726012             -74.050389   29268
# 3       Astor Place             40.719282             -74.071262   29278
# 4  Marin Light Rail             40.714584             -74.042817   29276
#
#      usertype  birth year  gender
# 0  Subscriber        1984       2
# 1  Subscriber        1989       2
# 2    Customer        1989       1
# 3    Customer        1969       0
# 4  Subscriber        1983       2

# %%
trips_df = pd.DataFrame()
trips_df = df.groupby(['Start Station Name','End Station Name']).size().reset_index(name = 'Number of Trips')
trips_df = trips_df.sort_values('Number of Trips', ascending = False)
trips_df["Start Station Name"] = trips_df["Start Station Name"].astype(str)
trips_df["End Station Name"] = trips_df["End Station Name"].astype(str)
trips_df["Trip"] = trips_df["Start Station Name"] + " to " + trips_df["End Station Name"]
trips_df = trips_df[:10]
trips_df = trips_df.drop(['Start Station Name', "End Station Name"], axis = 1)
trips_df = trips_df.reset_index()
#trips_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-b9b68ff3ab62> in <module>
#       1 trips_df = pd.DataFrame()
# ----> 2 trips_df = df.groupby(['Start Station Name','End Station Name']).size().reset_index(name = 'Number of Trips')
#       3 trips_df = trips_df.sort_values('Number of Trips', ascending = False)
#       4 trips_df["Start Station Name"] = trips_df["Start Station Name"].astype(str)
#       5 trips_df["End Station Name"] = trips_df["End Station Name"].astype(str)
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\anaconda3\envs\PythonData38\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'Start Station Name'
